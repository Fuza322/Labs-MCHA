# %% [markdown]
# # Лабораторная работа №5 #
# # "Метод сеток решения волнового уравнения" #
# ## Цель работы: ##
# 1. Изучить метод разностных аппроксимаций для волнового уравнения, составить алгоритмы решения волнового уравнения методом сеток, применимым для организации вычислений на ПЭВМ;
# 2. Составить программы волнового уравнения по разработанным алгоритмам;
# 3. Выполнить тестовые примеры и проверить правильность работы программ;
# 4. Получить численное решение волнового уравнения.

# %% [markdown]
# ## ЗАДАНИЕ К ЛАБОРАТОРНОЙ РАБОТЕ №5 ##
# ### Задача 1: ###
# Рассчитать колебания ***u(x,t)***.
#
# Продольные колебания ***u(x,t)*** тяги описываются уравнением:
# ![](https://sun9-50.userapi.com/c858524/v858524659/41c5b/pccPVLG2vMM.jpg)
# Тяга имеет длину ***L*** и закреплена на концах. Захватив тягу в центре (рис. 2.10), её деформируют так, что продольное перемещение становится равным ***Δu***:
# ![](https://sun9-49.userapi.com/c858524/v858524659/41c6a/VKKAjuz38s0.jpg)
# Затем тяга освобождается.
#
# Рассчитайте колебания ***u(x,t)*** при заданных в табл. 2.12 параметрах.

# %% [markdown]
# ### Задача 2 ###
# Рассчитать колебания тонкой пластины. Колебания тонкой пластины (рис. 2.11) без учета потерь на трение описываются нормированным волновым уравнением вида:
# ![](https://sun9-8.userapi.com/c858524/v858524659/41c84/iaW4Bg1sv4c.jpg)
# ![](https://sun9-14.userapi.com/c858524/v858524659/41c8c/Z1k27vWoZlA.jpg)
# Рассчитать колебания пластины при заданных в табл. 2.13 размерах **a** и **b**.
#
# *При следующих граничных условиях*: ***Г1, Г2, Г3, Г4***.
#
# *И при следующих начальных условиях*:
# ![](https://sun9-15.userapi.com/c858524/v858524659/41cb2/2YIrXgQUC7s.jpg)
# ![](https://sun9-23.userapi.com/c858524/v858524659/41cc3/0jah3Lu0fXY.jpg)

# %% [markdown]
# ## Tеоретические сведения ##
# ### Волновое уравнение ###
# Рассмотрим смешанную задачу для волнового уравнения:
# ![](https://sun9-29.userapi.com/c858524/v858524659/41cf8/JiiV-WUIkLU.jpg)
# Будем предполагать, что задача (2.63)–(2.65) имеет единственное
# решение ***u(х,t) ∈ C <sub>4</sub>(D^)***, ***D^ =*** {**(x,t):0≤x≤1, 0≤t≤T}** – замкнутый прямоугольник.
# ### Разностная схема ###
# Будем использовать сетки, построенные на замкнутом прямоугольнике ***D^***
# в ***лабораторной работе №14***, и соответствующие обозначения сеточных функций.
#
# Заменяем в уравнении (2.63) частную производную ***u<sub>tt</sub>''*** приближенно второй разностной производной в направлении ***t***, а частную производную – ***u<sub>xx</sub>''*** заменяем второй разностной производной в направлении ***х*** и, заменив ***u*** на ***у***, приходим к разностному уравнению
#
# ![](https://sun9-19.userapi.com/c858524/v858524017/42e18/Z4DjSWhXPFQ.jpg)
# ![](https://sun9-45.userapi.com/c858524/v858524017/42e10/QqaWHuE46Jg.jpg)
#
# Это уравнение можно разрешить явно относительно ***y<sub>k</sub><sup>v+1</sup>***. Но для того, чтобы
# находить значения разностного решения на ***(v + 1)***-oм слое, требуется иметь уже
# вычисленные значения искомого решения на двух предыдущих слоях.
#
# Поэтому нужно получить разностное решение сначала отдельно на слоях, отвечающих значениям ***v = 0 и v = 1***. В этом нам помогут начальные условия.
#
# Прежде всего, используя первое начальное условие (2.64), задаем
# ![](https://sun9-13.userapi.com/c858524/v858524017/42e62/x0O2bFINnVI.jpg)
# ![](https://sun9-38.userapi.com/c857032/v857032017/42a31/MV-4c9tKs1Y.jpg)
#
# Правая часть формулы (2.68) аппроксимирует многочлен Тейлора, поскольку согласно (2.64) ***u(x<sub>k</sub>, 0) = p<sub>k</sub>, u<sub>t</sub>'(x<sub>k</sub>, 0) = q<sub>k</sub>***, а из уравнения (2.63) для частных производных решения задачи (2.63)–(2.65) вытекает связь ***u<sub>tt</sub>''(x<sub>k</sub>, 0) = f(x<sub>k</sub>, 0) + u<sub>k</sub>''(x<sub>k</sub>, 0)***.
#
# Наконец, согласно краевым условиям (2.65) имеем
# ![](https://sun9-23.userapi.com/c857032/v857032017/42a62/Mi8D-nzycFc.jpg)
# Теперь разностная схема (2.63)–(2.65) полностью определена. Эта схема явная трехслойная (см. шаблон на рис. 2.7), условно устойчивая в некоторых естественных нормах.
#
# Если ***h ➜ 0, τ ➜ 0***, причем ***τ / h ≤ c<1, c = const***, то решение у разностной схемы (2.66) сходится к рассматриваемому решению ***u*** задачи (2.63)–(2.65) в следующем смысле:
# ![](https://sun9-55.userapi.com/c857032/v857032017/42ab1/uZrX3RMqWxY.jpg)
# Схема (2.66) имеет второй порядок точности и по ***h***, и по ***τ***.
# ### Понятие о методе прямых ###
# Если в задаче (2.63)–(2.65) ввести дискретность только по ***х***, то мы придем к системе линейных обыкновенных дифференциальных уравнений
# ![](https://sun9-12.userapi.com/c857032/v857032017/42ad6/8ToiP0lUu2A.jpg)
# При сделанном предположении относительно гладкости решения задачи (2.63)–(2.65) имеем
# ![](https://sun9-6.userapi.com/c857032/v857032017/42ade/eCwpf5l-Jn0.jpg)
# ![](https://sun9-11.userapi.com/c857032/v857032017/42afe/zT2AERAIB5M.jpg)
#
# где ***y<sub>1</sub>(t), y<sub>2</sub>(t), ..., y<sub>N-1</sub>(t)*** – это решение задачи Коши (2.63) – (2.65).
#
# Данный метод называется ***методом прямых***, поскольку приближенное решение задачи (2.63)–(2.65) ищется на прямых ***x = x<sub>k</sub>***, ***k = 1, 2, ...,N–1***, расположенных в плоскости ***xt***.
#
# Разностный же метод часто называется ***методом сеток***.

# %% [markdown]
# ## Программная реализация ##

# %% [markdown]
# ## Задание 1 ##

# %%
from matplotlib import pyplot as graphic
import numpy as nump

# %% [markdown]
# ### Исходные данные: ###

# %%
fun = lambda x: - nump.fabs((x - leng / 2) * 2 * Δ_u / leng) + Δ_u
ρ = 5900
n_x = 100
n_t = 10000
Elasticity = 120000000000
leng = 0.18
Δ_u = 0.002
T = 1e-3

# %% [markdown]
# ### Решение задачи: ###

# %%
dx = leng / n_x
dt = T / n_t
Cond = nump.sqrt(Elasticity / ρ) * dt / dx
if Cond > 1:
    print('---------------------------------------------------')
    print('ERROR!!! The convergence condition is not satisfied')
    print('---------------------------------------------------')
values_on_OX = nump.linspace(0, leng, n_x)
 #------------------------------------------------------------------------
mas = nump.zeros((n_t, n_x))
mas[0] = [fun(x) for x in values_on_OX]
mas[1, 1:-1] = [fun(values_on_OX[i]) * (1 - dt ** 2 / 2) for i in range(1, n_x - 1)]
#------------------------------------------------------------------------
for i in range(1, n_t - 1):
    mas[i + 1, 1: - 1] = Cond ** 2 * (mas[i, 2: ] - 2 * mas[i, 1: -1] + mas[i, : -2]) + 2 * mas[i, 1: -1] - mas[i-1, 1: -1]
values_on_OX = nump.linspace(0, leng, n_x)

# %% [markdown]
# ### Вывод результата: ###

# %%
for i in range(0, n_t, int(n_t / 20)):
	graphic.plot(values_on_OX, mas[i])
	graphic.xlabel('X', size = 20)
	graphic.ylabel('U(X, t)', size = 20)
graphic.grid()
graphic.show()

# %% [markdown]
# ## Задание 2 ##

# %%
import numpy as nump
from matplotlib import pyplot as graphic
import seaborn as plate

# %% [markdown]
# ### Исходные данные: ###

# %%
A = 2
B = 1
u_0 = lambda x, y: nump.arctan(nump.cos(nump.pi * x / A))
u_0_part = lambda x, y: nump.sin(2 * nump.pi * x / A) * nump.sin(nump.pi * y / B)
T = 4
n_x = 100
n_y = 100
n_t = 5000

# %% [markdown]
# ### Решение задачи: ###

# %%
δ_x = A / n_x
δ_y = B / n_y  
δ_t = T / n_t  
Cond = δ_t / δ_x + δ_t / δ_y 
if Cond > 1:
    print('---------------------------------------------------')
    print('ERROR!!! The condition is not satisfied')
    print('---------------------------------------------------')
#------------------------------------------------------------
x_values = nump.linspace(-A / 2, A / 2, n_x)
y_values = nump.linspace(-B / 2, B / 2, n_y)
mas = nump.zeros((n_t, n_x, n_y))
for i in range(n_x):
    for j in range(n_y):
        mas[0, i, j] = u_0(x_values[i], y_values[j])  
for i in range(1, n_x - 1):
    for j in range(1, n_y - 1):
        mas[1, i, j] = (u_0(x_values[i], y_values[j]) + u_0_part(x_values[i], y_values[j]) * δ_t + δ_t ** 2 / (2 * δ_x ** 2) * (mas[0, i + 1, j] - 2 * mas[0, i, j] + mas[0, i - 1, j]) + δ_t ** 2 / (2 * δ_y ** 2) * (mas[0, i, j + 1] - 2 * mas[0, i, j] + mas[0, i, j - 1]))            
mas[1, 1: -1, 0] = mas[1, 1: -1, 1]
mas[1, 1: -1, -1] = mas[1, 1: -1, -2]   
for t in range(1, n_t - 1):
    mas[t + 1, 1: -1, 1: -1] = (2 * mas[t, 1: -1, 1: -1] - mas[t - 1, 1: -1, 1: -1] + δ_t ** 2 / δ_x ** 2 * (mas[t, : -2, 1: -1]- 2 * mas[t, 1: -1, 1: -1] + mas[t, 2:, 1: -1]) + δ_t ** 2 / δ_y ** 2 * (mas[t, 1: -1, : -2] - 2 * mas[t, 1: -1, 1: -1] + mas[t, 1: -1, 2:]))     
    mas[t + 1, 1: -1, 0] = mas[t + 1, 1: -1, 1]
    mas[t + 1, 1: -1, -1] = mas[t + 1, 1: -1, -2]

# %% [markdown]
# ### Вывод результата: ###

# %%
for i in range(0, len(mas), 300):
    plate.heatmap(mas[i].T, cmap='BuPu', vmin=mas.min(), vmax=mas.max())
    graphic.show()
