# %% [markdown]
# # Лабораторная работа №3 #
# ## Цель работы: ##
# 1) Изучить метод разностных аппроксимаций для уравнения теплопроводности;
#
# 2) Составить алгоритмы решения уравнения теплопроводности методом сеток, применимым для организации вычислений на ПЭВМ;
#
# 3) Составить программы решения уравнения теплопроводности по разработанным алгоритмам;
#
# 4) Выполнить тестовые примеры и проверить правильность работы программ;
#
# 5) Получить численное решение заданного уравнения теплопроводности.

# %% [markdown]
# ## Условие задачи: ##
# ### Задача 2 ###
# Промоделировать стационарные процессы теплопроводности стержня в зависимости от входных данных задачи – переменного коэффициента теплопроводности ***k(x)*** и плотности источников тепла ***f(x)***:
# ### *Порядок решения*: ###
# Составить разностную схему второго порядка точности для решения указанной задачи.
#
# 1. Взять исходные данные из первого набора параметров для первой задачи.
#
# 2. Шаг сетки положить равным ***h = (b - a) / 150***.
# 3. Промоделировать процесс в зависимости от коэффициента теплопроводности ***k(x)***:
# 4. (a) Полагать, что стержень состоит из двуx материалов с различными коэффициентами теплопроводности ***k(x)***:
# ![](https://sun9-8.userapi.com/c854224/v854224559/15904b/77qho0-fbXc.jpg)
# 4. (б) Пусть стержень состоит из треx материалов с различными свойствами:
# ![](https://sun9-9.userapi.com/c854224/v854224559/159079/eNIB3bDqXcs.jpg)
# 5. Промоделировать процесс теплопроводности в зависимости от правой части – функции ***f(x)***, предполагая, что ***f(x)*** − точечный источник тепла. Задать точечный источник тепла можно следующим образом: ***f(x) = c * δ(x - x<sub>0</sub>)***, где ***c*** − некоторая константа (мощность источника);***δ(x)*** − дельта-функция; ***x<sub>0</sub>*** − точка из отрезка **[a,b]**, в которой располагается источник.
#
# Рассмотреть следующие варианты расположения источника:
#
# а) точечный источник поставлен в середину отрезка **[a,b]**;
#
# b) два одинаковых по мощности источника поставлены в разные точки
# отрезка, симметричные относительно середины отрезка;
#
# c) два различных по мощности источника поставлены симметрично;
#
# d) предложить свой вариант расположения источников.
#
# ### Задача 3 ###
# Промоделировать нестационарные процессы теплопроводности в зависимости от входных данных задачи − коэффициента теплопроводности и начальной температуры:
# ![](https://sun9-62.userapi.com/c854224/v854224559/159135/IX0Wl6cOyN8.jpg)
# Исходные данные приведены в табл. 2.6.
# ### *Порядок решения*: ###
# 1. Найти приближенное решение задачи с шагами ***τ = 0.05*** и ***h = 0.01***, используя явную разностную схему. Построить графики решений при значениях ***t = 0,5<sup>τ</sup>, 20<sup>τ</sup>, 200<sup>τ</sup>***.
# 2. Экспериментально определить момент времени ***t***, при котором происходит установление процесса (визуально).
# 3. Произвести анимацию процесса установления.
# 4. Исследовать, как влияет начальная температура на процесс установления, взяв другие функции ***φ(x)*** (согласованные с граничными условиями).
#
# ### Задача 4 ###
# Промоделировать нестационарные процессы теплопроводности в зависимости от входных данных задачи. Найти приближенное решение начально-краевой задачи для уравнения теплопроводности:
# ![](https://sun9-21.userapi.com/c854224/v854224175/160fe2/t0UqurBCAjM.jpg)
# Исходные данные приведены в табл. 2.7.
#
# В задаче взять входные данные ***ua***, ***ub*** из задачи 3. Использовать явную разностную схему. Взять ***h = (b-a) / 10***; шаг ***τ*** выбрать из условия устойчивости. Изобразить графики зависимости приближенного решения от ***x*** при ***t = 0***, ***2τ***, ***4τ*** , ...***T***.
#
# **УКАЗАНИЕ.** Условие устойчивости для явной разностной схемы имеет
# вид ***τ*** ****≤ 0.5(h<sup>2</sup>/ k)***.
#
# **ПРИМЕЧАНИЕ.** Для нахождения решения стационарного уравнения теплопроводности необходимо дважды проинтегрировать его.
#
# Стационарное уравнение теплопроводности имеет следующий вид:
# ![](https://sun9-45.userapi.com/c854224/v854224175/1610e8/2MDoYj9N-OU.jpg)
# Проинтегрируем полученное соотношение еще раз и получим:
# ![](https://sun9-67.userapi.com/c854224/v854224175/1610ef/eeRiSpnnj4s.jpg)
# Константы ***c<sub>1</sub>***, ***c<sub>2</sub>*** находятся из граничных условий:
# ![](https://sun9-63.userapi.com/c854224/v854224175/16113c/eINSXubLKRw.jpg)

# %% [markdown]
# ## Теоретические сведенья ##
# Пусть стоит задача, в которой требуется найти непрерывную на замкнутом прямоугольнике ***D^*** функцию ***u(x, t)***, которая на ***D'*** удовлетворяет уравнению теплопроводности
# ![](https://sun9-41.userapi.com/c854224/v854224847/161ac6/w-AX_MWr9Gg.jpg)
# которое при ***t = 0*** удовлетворяет начальному условию
# ![](https://sun9-5.userapi.com/c854224/v854224847/161ad6/mIeChnhDCNk.jpg)
# а при ***х = 0*** и ***х = 1*** подчиняется краевым условиям
# ![](https://sun9-33.userapi.com/c854224/v854224847/161af1/Upjd9jn6QIw.jpg)
# где ***f(x, t)***, ***s(x)***, ***p(t)***, ***q(t)*** − заданные достаточно гладкие функции, причем
# ***s(0) = p(0)***, ***s(l) = q(l)***.
#
# Такая задача называется ***смешанной задачей***, поскольку она содержит как начальные условия, так и краевые условия. Известно, что у поставленной задачи существует единственное решение ***u(х, t)***. Мы будем предполагать, что это решение имеет на замкнутом прямоугольнике непрерывные частные производные ***∂u/t***, ***∂<sup>2</sup>u/∂t<sup>2</sup>***, ***∂<sup>2</sup>u/∂x<sup>2</sup>***, ***∂<sup>4</sup>u/∂x<sup>4</sup>***.
# ### Cетки нормы ###
# Пусть ***h = 1/N***, ***τ = T/M*** − шаги по ***x*** и ***t**, где ***N***, ***M*** – натуральные числа, а также
#
# ***x<sub>k</sub> = kh***,   ***t<sub>v</sub> = vτ***,   ***u<sub>k</sub><sup>v</sup> = u(x<sub>k</sub>,t<sub>v</sub>)***.
#
# Построим сетки:
# ![](https://sun9-24.userapi.com/c858524/v858524610/41ecf/XTxWcOQzPdU.jpg)
# Сетка ***ω<sub>h</sub>**** состоит из узлов сетки ***ω<sub>h</sub>***.
# Эти узлы расположены на трех сторонах прямоугольника ***D^***, на которых заданы начальное и краевые условия. Сетка ***ω<sub>h</sub>'*** состоит из остальных узлов сетки ***ω<sub>h</sub>***. Зададим для сеточных функций, определенных на ***ω<sub>h</sub>*** или на ***ω<sub>h</sub>'***, следующие нормы:
# ![](https://sun9-49.userapi.com/c858524/v858524610/41f0c/u6MWhD5X1Ho.jpg)
# ### Разностные схемы ###
# Введем разностный оператор **Λ**:
# ![](https://sun9-63.userapi.com/c858524/v858524610/41f1c/4ZHnAolMgFM.jpg)
# Здесь под выражением **Λy<sub>k</sub><sup>v</sup>** подразумевается значение сеточной функции **Λy** в точке с координатами ***(x<sub>k</sub> ,t<sub>v</sub>)***, т.е. **(Λy)<sub>k</sub><sup>v</sup>**.
# ![](https://sun9-22.userapi.com/c858524/v858524610/41f23/DZFwV1UN96o.jpg)
# Зададим на сетке ***ω<sub>h</sub>**** тождественный оператор
# ![](https://sun9-29.userapi.com/c858524/v858524610/41f54/xrgHzwzApYQ.jpg)
# и сеточную функцию
# ![](https://sun9-22.userapi.com/c858524/v858524610/41f5c/EuaBOFonQik.jpg)
# Рассмотрим две разностные схемы:
# ![](https://sun9-33.userapi.com/c858524/v858524610/41f63/oZjptcaxq_Q.jpg)
# Здесь и далее индекс ***k*** изменяется от **1** до **N–1**, ***v = l, 2,.., М***.
#
# Шаблоны разностных уравнений (2.17) и (2.19) представлены соответственно на рис.(2.2) и (2.3).
# ![](https://sun9-47.userapi.com/c858524/v858524610/41f71/7gCKQu73BzY.jpg)
# Обе разностные схемы (2.17), (2.18) и (2.19), (2.20) называются ***двухслойными***, т.к. шаблоны разностных уравнений (2.17) и (2.19)
# содержат узлы, лежащие только на двух временных слоях − подмножествах сетки **ω<sup>h</sup>***,отвечающих значениям времени ***t=t<sub>v-1</sub>*** и ***t=t<sub>v</sub>***. Слой, находящийся на горизонтальной прямой **t = t<sub>v-1</sub>***, называется **нижним**, а слой, находящийся на горизонтальной прямой **t = t<sub>v</sub>***, − **верхним**. Разностные схемы (2.17), (2.18) и (2.19), (2.20) отличаются тем, что в уравнении (2.17) оператор **Λ** действует на
# нижнем слое, а в уравнении (2.19) оператор **Λ** вынесен на верхний слой, и, кроме того, значения правой части ***f<sub>k</sub> <sup>v-1</sup> = f(x<sub>k</sub>, t<sub>v-1</sub>)*** и ***f<sub>k</sub> <sup>v</sup> = f(x<sub>k</sub>, t<sub>v</sub>)*** берутся на разных слоях. Ограничимся пока предложенным формальным описанием двух разностных схем. Их качественное различие будет описано далее в данной лабораторной работе.
# ### Аппроксимация ###
# поставляя, с одной стороны, дифференциальное уравнение (2.10), а, с
# другой стороны, разностные уравнения (2.17) и (2.19), видим, что частной производной ***u<sub>t</sub>'*** отвечает разностная производная
# ![](https://sun9-59.userapi.com/c858524/v858524610/41f7e/9Cdyli_JWwk.jpg)
# а частной производной ***-u<sub>xx</sub>''*** соответствует разностная производная второго порядка в направлении ***х***, образуемая с противоположным знаком с помощью оператора **Λ** (2.14).
#
# Пусть ***u(х,t)*** − решение задачи (2.10)−(2.12). Поскольку частные производные ***∂<sup>2</sup>u/∂t<sup>2</sup>*** и ***∂<sup>4</sup>u/∂x<sup>4</sup>*** по предположению непрерывны
# следовательно, ограничены на замкнутом прямоугольнике
# ***D^***, и, то согласно (2.14),
# ![](https://sun9-69.userapi.com/c858524/v858524610/41f95/WaBi3wHyw_k.jpg)
# ![](https://sun9-9.userapi.com/c858524/v858524610/41f8d/NcnE-x0dnZM.jpg)
# а ***c<sub>1</sub>, c<sub>2</sub>*** (2.23) − некоторые постоянные, не зависящие от ***h, τ, k, v***.
#
# В силу непрерывности частных производных ***u<sub>t</sub>'*** и ***-u<sub>xx</sub>''***, на ***D^*** решение задачи (2.10)− (2.12) удовлетворяет уравнению (2.10) на замкнутом прямоугольнике ***D^***.
#
# Следовательно, выполняется равенство
# ![](https://sun9-45.userapi.com/c858524/v858524435/430fb/wi4f8fCDdQg.jpg)
# для ***k = 1, 2, ..., N-1, v = 1, 2,..., M***, т.е., в частности, и для ***t<sub>v-1</sub> = 0***.
#
# Согласно (2.21), (2.22), (2.23) невязка ***ᴪ<sub>1</sub>*** решения ***u*** задачи (2.10)–(2.12)
# для разностного уравнения (2.17) имеет следующее выражение:
# ![](https://sun9-25.userapi.com/c858524/v858524435/43102/XTTR8OHhOyU.jpg)
# Отсюда с учетом (2.23) получаем
# ![](https://sun9-5.userapi.com/c858524/v858524435/43133/ZITov6jroQA.jpg)
# Аналогично находим
# ![](https://sun9-43.userapi.com/c858524/v858524435/4313a/e8-4MEl7-Wc.jpg)
# где ***ᴪ<sub>2</sub>*** − невязка решения ***u*** задачи (2.10)−(2.12) для разностного уравнения (2.19).
#
# Таким образом, оба разностных уравнения (2.17) и (2.19) аппроксимируют дифференциальное уравнение (2.10) на решении ***u*** задачи (2.10)–(2.12) со вторым порядком по ***h*** и с первым порядком по ***τ***.
#
# Дополнительные условия, т. е. начальное условие (2.11) и краевые условия (2.12), аппроксимируются на сетке ***ω<sub>h</sub>**** с помощью тождественного оператора ***l<sup>h</sup>*** условием (2.18) или соответственно условием (2.20) точно, т.е. невязка решения u задачи (2.10)−(2.12) для условий (2.18) и (2.20) равна нулю на сетке ***ω<sub>h</sub>****.
#
# Итак, обе разностные схемы (2.17), (2.18) и (2.19), (2.20) с точки зрения аппроксимации задачи (2.10)−(2.12) обладают одинаковой по порядку относительно ***h*** и ***τ*** гарантируемой точностью.
# ### Вычеслительные алгоритмы ###
# Разрешив разностное уравнение (2.17) относительно ***y<sub>k</sub><sup>v</sup>***, получим
# ![](https://sun9-8.userapi.com/c858524/v858524435/43187/p6Adcb4U47g.jpg)
# Поскольку ***y<sub>k</sub><sup>0</sup>***,***y<sub>0</sub><sup>v</sup>***,***y<sub>N</sub><sup>v</sup>***, ***k = 1, 2,..., N − 1***, ***v = 0, 1,..., M*** известны (они
# задаются на ***ω<sub>h</sub>**** условием (2.18)), решение разностной схемы (2.17), (2.18)
# находится по формуле (2.27) явно, слой за слоем. Поэтому разностная схема (2.17), (2.18) называется ***явной***.
#
# Разностное уравнение (2.19) с учетом (2.14) может быть записано в виде
# ![](https://sun9-49.userapi.com/c858524/v858524435/4318e/jH9CkqOIiQ4.jpg)
# Согласно (2.15), (2.16), (2.20) имеем также
# ![](https://sun9-29.userapi.com/c858524/v858524435/43195/P-5LKWN2q9g.jpg)
#
# Таким образом, если ***y<sub>k</sub><sup>v-1</sup>***, ***k = 1, 2, ..., N−1***, известны (в частности, **y<sub>k</sub><sup>0</sup>***, ***k = 1, 2, ..., N−1***, заданы условием (2.20)), то для нахождения решения разностной схемы (2.19), (2.20) на следующем ***v***-м слое нужно решить трехточечное разностное уравнение (2.28) с краевыми условиями первого рода (2.29), т.е. разностную краевую задачу. Поэтому разностная схема (2.19), (2.20) называется ***неявной***.
#
# Для нахождения разностного решения на ***v***-м слое может быть применен метод прогонки, [2] поскольку для задачи (2.28), (2.29) достаточные условия выполнены (проверьте, положив ***k = j, y<sub>k</sub><sup>v</sup> =  z<sub>j</sub>, y<sub>k</sub><sup>v-1</sup> = z<sub>j+-1</sub> , -y<sub>k</sub><sup>v-1</sup> = τf<sub>k</sub><sup>v</sup>= F<sub>j</sub>)***. При этом число выполняемых арифметических действии для нахождения разностного
# решения на одном слое имеет величину порядка ***O(N)***, т. е. по порядку относительно ***N*** не больше, чем при применении явной формулы (2.27) для схемы (2.17), (2.18).
# ### Устойчивость и сходимость ###
# Так как дополнительные условия (2.11), (2.12) аппроксимируются в разностных схемах (2.17), (2.18) и (2.19), (2.20) на сетке ***ω<sub>h</sub>**** точно, то нам будет достаточно исследовать устойчивость только по правой части. Остановимся сначала на разностной схеме (2.17), (2.18). Для исследования ее устойчивости по правой части нужно рассмотреть решение ***z*** вспомогательной разностной задачи:
# ![](https://sun9-47.userapi.com/c858524/v858524435/431fc/yK-Ua7NTr4E.jpg)
# ![](https://sun9-55.userapi.com/c858524/v858524435/43203/hGYQdKwqtow.jpg)
# Разрешив разностное уравнение (2.30) относительно ***z<sub>k</sub><sup>v</sup>*** , аналогично (2.27) получаем
# ![](https://sun9-6.userapi.com/c858524/v858524435/43225/CzAre67AauQ.jpg)
# ![](https://sun9-58.userapi.com/c858524/v858524435/4322c/ND8JZ1xqxUw.jpg)
# Кроме того, в соответствии с (2.31) имеем
# ![](https://sun9-30.userapi.com/c858524/v858524435/43241/0BqvUeoq4c4.jpg)
# Предположим, что ***τ*** и ***h*** удовлетворяют следующему условию:
# ![](https://sun9-35.userapi.com/c858524/v858524435/43248/VjCQ770Lg6E.jpg)
# Отсюда и из (2.32), (2.33) вытекает неравенство
# ![](https://sun9-48.userapi.com/c858524/v858524435/43257/tXj0AXWwqk4.jpg)
# ![](https://sun9-34.userapi.com/c858524/v858524435/43267/knh7Oi6x8MM.jpg)
# Следовательно,
# ![](https://sun9-64.userapi.com/c858524/v858524435/4326e/X1EosW8pEq0.jpg)
# или окончательно
# ![](https://sun9-16.userapi.com/c858524/v858524435/43275/gmuhdJNwdHA.jpg)
# Полученное неравенство (2.36) для решения задачи (2.30), (2.31), в которой постоянная ***T*** не зависит от ***h*** и ***τ***, а также от функции ***ℰ***, означает устойчивость разностной схемы (2.17), (2.18) по правой части при условии (2.34). Можно доказать, что нарушение условия (2.34) может привести к нарушению устойчивости разностной схемы (2.17), (2.18). В частности, если ***h → 0***, ***τ → 0***, а ***τ / h<sup>2</sup> ≥ const > 1/2***, то разностная схема (2.17), (2.18) будет неустойчива.
# Для исследования устойчивости разностной схемы (2.19), (2.20) зададим на ***ω<sub>h</sub>'*** произвольную сеточную функцию ***ℰ*** рассмотрим разностную задачу
# ![](https://sun9-47.userapi.com/c858524/v858524435/432a2/1SwPS7GyXRY.jpg)
# не накладывая никаких ограничений на соотношение шагов ***τ*** и ***h***. Задачу (2.37), (2.38) можно аналогично (2.28), (2.29) записать в следующем виде:
# ![](https://sun9-4.userapi.com/c858524/v858524435/432a9/AduiTnqYYRE.jpg)
# Если ***z<sub>k</sub><sup>v-1</sup>, k = 1, 2,..., N - 1***, известны (в частности, по условию (2.38) ***z<sub>k</sub><sup>0</sup> = 0, k = 0, 1,..., N***), то, как отмечалось ранее, для разностной задачи (2.39), (2.40), где ***v*** фиксировано, выполнены условия (2.12). Следовательно, по лемме эта задача однозначно разрешима на ***v***-м слое.
# ![](https://sun9-4.userapi.com/c858524/v858524184/4347b/xD4jc3X8-Qw.jpg)
# ![](https://sun9-11.userapi.com/c858524/v858524184/43569/SwNOPnDLVGA.jpg)
# Из полученного неравенства с учетом (2.41) вытекает неравенство (2.35) и в конечном счете оценка (2.36), что и означает устойчивость по правой части разностной схемы (2.19), (2.20) при любом соотношении шагов ***τ*** и ***h***.
#
# Итак, поскольку дополнительные условия (2.11), (2.12) аппроксимируются на ***ω<sub>h</sub>**** точно, то из аппроксимации (см. (2.25), (2.26)) и установленной устойчивости по правой части в силу основной теоремы теории разностных схем вытекает сходимость решений разностных схем (2.17), (2.18) и (2.19), (2.20) к решению задачи (2.10)−(2.12) со вторым порядком по ***h*** и с первым порядком по ***τ***, т.е.
# ![](https://sun9-49.userapi.com/c858524/v858524184/4369b/wC-y_poXTcA.jpg)
# При этом в случае явной схемы (2.17), (2.18) предполагается выполнение условия (2.34).
#
# **Определение.** Разностная схема, устойчивая прилюбом соотношении шагов ***τ*** и ***h***, называется ***абсолютно устойчивой**, а устойчивая при ограничениях на ***τ*** и ***h*** − ***условно устойчивой***.
#
# Недостатком разностной схемы (2.17), (2.18) является ее условная устойчивость (ограничение (2.34) является жестким для шага ***τ*** по времени). Преимущество − простота счета по явной формуле (2.27) и возможность распространения на задачу Коши (когда условие (2.11) задано на всей оси ***х***, а краевые условия (2.12) отсутствуют). В случае смешанной задачи (2.10)−(2.12) предпочтение отдают неявной абсолютно устойчивой разностной схеме (2.19), (2.20). Разностная краевая задача (2.28), (2.29) при переходе на каждый следующий слой решается методом прогонки весьма эффективно.

# %% [markdown]
# # Программная реализация

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import sympy as sp
import numpy as np
import math

# %% [markdown]
# ## Задача №2

# %% [markdown]
# #### Начальные условия для задачи №2

# %%
u_a = 1.5
u_b = 2.5
y_a = 3
y_b = -3
k_1 = 80
k_2 = 1
k_3 = 20
x_0 = 100
c = u_a + (u_b - u_a) / 2
h = (u_b - u_a) / 150
x, t = sp.symbols('x t')
k = sp.Piecewise( (k_1, x < u_a + (u_b - u_a) / 3), (k_3, u_a + 2 * (u_b - u_a) / 3 <= x), (k_2, True), )
source = [(100, u_a + (u_b - u_a) / 2)]

# %%
def z2_solution(a, b, y_a, y_b, h, delta_function_s_integral, k_expr, sources):
    l, r = sp.symbols('l r')
    a_b = sp.lambdify((l, r), h * (sp.integrate(1 / k_expr, (x, l, r))) ** (-1))
    n = int((b - a) / h) + 1
    matrix = np.zeros(shape = (n, n))
    t = np.zeros(shape = (n, 1))
    xs = np.linspace(a, b, n)
    matrix[0, 0] = matrix[-1, -1] = 1
    t[0] = y_a
    t[-1] = y_b
    for i in range(1, n - 1):
        matrix[i, i - 1] = a_b(xs[i - 1], xs[i])
        matrix[i, i] = -a_b(xs[i - 1], xs[i]) - a_b(xs[i], xs[i + 1])
        matrix[i, i + 1] =  a_b(xs[i], xs[i + 1])
        t[i] = -h * sum(delta_function_s_integral(xs[i], x_0_i, ci) for ci, x_0_i in sources)
    return xs, np.linalg.solve(matrix, t)

# %% [markdown]
# #### Решение задачи №2

# %%
xs, ys = z2_solution(u_a, u_b, y_a, y_b, h, delta_function_s_integral, k, source)
plt.plot(xs, ys)
plt.grid()
plt.show()

# %% [markdown]
# #### Задача №2: Решение других вариантов задачи с разными плотностями

# %%
u_a = 0
u_b = 1
y_a = 0
y_b = 0
x_0 = 100
c = u_a + (u_b - u_a) / 2
h = (u_b - u_a) / 150
sources = [ [(10, u_a + (u_b - u_a) / 2)], [(10, u_a + (u_b - u_a) / 4), (10, u_a + 3 * (u_b - u_a) / 4)], [(10, u_a + (u_b - u_a) / 4), (50, u_a + 3 * (u_b - u_a) / 4)], ]
for k_1, k_2 in [[1, 100], [100, 1]]:
    k = sp.Piecewise( (k_1, x < u_a + (u_b - u_a) / 2), (k_2, True), )
    for source in sources:
        xs, ys = z2_solution(u_a, u_b, y_a, y_b, h, delta_function_s_integral, k, source)
        plt.plot(xs, ys, label = '{} {} {}'.format(k_1, k_2, source))
        plt.legend()
        plt.grid()
        plt.show()
for k_1, k_2, k_3 in [ [1, 3, 9], [9, 3, 1], [1, 2, 1], [20, 1, 20] ]:
    k = sp.Piecewise( (k_1, x < u_a + (u_b - u_a) / 3), (k_3, u_a + 2 * (u_b - u_a) / 3 <= x), (k_2, True), )
    for source in sources:
        xs, ys = z2_solution(u_a, u_b, y_a, y_b, h, delta_function_s_integral, k, source)
        plt.plot(xs, ys, label = '{} {} {} {}'.format(k_1, k_2, k_3, source))
        plt.legend()
        plt.grid()
        plt.show()

# %% [markdown]
# ## Задача 3

# %%
def z3_solution(x_h, t_h, a, b, k, T_t, g1, g2, delta_function_s_integral, f):
    x_h_step = 1 + int((b - a) / x_h)
    t_h_step = 1 + int(T_t / t_h)
    x_hs = np.linspace(a, b, x_h_step)
    t_hs = np.linspace(0, T_t, t_h_step)
    matrix = np.zeros(shape = (t_h_step, x_h_step))
    matrix[0, 1: -1] = np.array([delta_function_s_integral(x_hs[i]) for i in range(1, x_h_step - 1)])
    matrix[:, 0] = np.array([g1(x_hs[0], t_hs[i]) for i in range(t_h_step)])
    matrix[:, -1] = np.array([g2(x_hs[-1], t_hs[i]) for i in range(t_h_step)])
    for i in range(1, t_h_step):
        for j in range(1, x_h_step - 1):
            matrix[i,j] = sum([k(x_hs[j] - x_h / 2) * t_h / x_h ** 2 * matrix[i - 1, j - 1], (1 - (k(x_hs[j] - x_h / 2) + k(x_hs[j] + x_h / 2)) * t_h / x_h ** 2) * matrix[i - 1, j], k(x_hs[j] + x_h / 2) * t_h / x_h ** 2 * matrix[i - 1, j + 1], t_h * f(x_hs[j], t_hs[i]) * (1 - math.exp(-t_hs[i])) ] )
    ax = plt.axes(projection ='3d')
    ax.set_ylabel('$T:$ Временная ось')
    ax.set_xlabel('$X:$ Пространственная ось')
    ax.set_zlabel('$Y:$ Ось значений')
    for i in range(0, t_h_step, 100):
        ax.plot3D(x_hs, np.array([t_hs[i]] * x_h_step), matrix[i, :])

# %% [markdown]
# #### Задача №3: условие задачи и вывод решения

# %%
a = 1.5
b = 5/2
g1 = sp.lambdify((x, t), 3)
g2 = sp.lambdify((x, t), 3)
f = sp.lambdify((x, t), x + x ** 0.5)
k = sp.lambdify(x, x ** (-1 / 3))
delta_function_s_integral = sp.lambdify(x, 12 * (x - 2) ** 2)
h_x = 0.05
h_t = 0.001
T_t = 500 * 0.001
z3_solution(h_x, h_t, a, b, k, T_t, g1, g2, delta_function_s_integral, f)
plt.show()

# %% [markdown]
# ## Задача 4

# %%
def z4_solution(a, b, k, T_t, delta_function_s_integral, g1, g2, f):
    x_h = (b - a) / 50
    x_h_step = int((b - a) / x_h) + 1
    t_h = 0.5 * x_h ** 2 / k
    t_h_step = int(T_t / t_h) + 1
    x_hs = np.linspace(a, b, x_h_step)
    t_hs = np.linspace(0, T_t, t_h_step)
    matrix = np.zeros(shape = (t_h_step, x_h_step))
    matrix[0, 1: -1] = np.array([delta_function_s_integral(x_hs[i], t_hs[0]) for i in range(1, x_h_step - 1)])
    matrix[ :, 0] = np.array([g1(x_hs[0], t_hs[i]) for i in range(t_h_step)])
    matrix[ :, -1] = np.array([g2(x_hs[-1], t_hs[i]) for i in range(t_h_step)])
    coefficient = np.array([k * t_h / x_h ** 2, 1 - 2 * k * t_h / x_h ** 2, k * t_h / x_h ** 2])
    for i in range(1, t_h_step):
        for j in range(1, x_h_step - 1):
            matrix[i][j] = matrix[i - 1, j - 1: j + 2].dot(coefficient) + t_h * f(x_hs[j], t_hs[i - 1])
    ax = plt.axes(projection='3d')
    ax.set_ylabel('$T:$ Временная ось')
    ax.set_xlabel('$X:$ Пространственная ось')
    ax.set_zlabel('$Y:$ Ось значений')
    for i in range(0, t_h_step, 10):
        ax.plot3D(x_hs, np.array([t_hs[i]] * x_h_step), matrix[i, :])

# %% [markdown]
# #### Задача №4: условие задачи и вывод решения

# %%
k = 1
T_t = 0.5
a = 0
b = 1
delta_function_s_integral = sp.lambdify((x, t), 0)
g1 = sp.lambdify((x, t), 0)
g2 = sp.lambdify((x, t), 0)
f = sp.lambdify((x, t), x)
z4_solution(a, b, k, T_t, delta_function_s_integral, g1, g2 , f)
plt.show()
